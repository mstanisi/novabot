# %%
pip install dataloader --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install datasets --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.prefix)
# Out:
# /home/user/jupyter-env

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.3

# %%
import re
import textwrap

# %%
with open('data/lunch.txt', 'r') as f:
    lunch = f.read() 
    
with open('data/nova.txt', 'r') as f:
    nova = f.read()

with open('data/ticket.txt', 'r') as f:
    ticket = f.read() 

with open('data/soft.txt', 'r') as f:
    soft = f.read() 

with open('data/zone.txt', 'r') as f:
    zone = f.read()

# %%
soft2 = set(soft.lower().split())
ticket2 = set(ticket.lower().split())
nova2 = set(nova.lower().split())
lunch2 = set(lunch.lower().split())
zone2 = set(zone.lower().split())

intersection1 = lunch2 & soft2
intersection2 = lunch2 & nova2
intersection3 = lunch2 & zone2
intersection4 = lunch2 & ticket2
intersection5 = soft2 & nova2
intersection6 = soft2 & zone2
intersection7 = soft2 & ticket2
intersection8 = nova2 & ticket2
intersection9 = nova2 & zone2
intersection10 = zone2 & ticket2

cutups1 = intersection1.union(intersection2, intersection3, intersection4, intersection5)
cutups2 = intersection6.union(intersection7, intersection8, intersection9, intersection10)
hoard = cutups1.union(cutups2)

# %%
hoard = list(hoard)
hoard = [x for x in hoard if not (x.isdigit() 
        or x[0] == '-' and x[1:].isdigit())]
chars_to_remove = [".",",","?","!",":","(",")"]
hoard = ["".join(ch for ch in string if ch not in chars_to_remove) for string in hoard]
hoard = [x for x in hoard if len(x) > 1]
hoard = [item.strip('"') for item in hoard]
hoard = [s for s in hoard if not s.startswith("-")]
hoard = [s for s in hoard if not s.endswith("-")]

# %%
print(hoard)
# Out:
# ['dollars', 'sear', 'new', 'dime', 'rioters', 'life', 'dwarfs', 'rail', 'bronze', 'nude', 'sub', 'stinger', 'willy', 'squeak', 'celluloid', 'department', 'worthy', 'bad', 'carried', 'times', 'spine', 'crushed', 'department', 'on', 'mother', 'operates', 'hottest', 'here', 'dismissed', 'conditions', 'wisdom', 'pattern', 'compatible', 'most', 'colonial', 'ornate', 'eats', 'holes', 'cubicles', 'alternative', 'al', 'wave', 'yonder', 'no', 'takes', 'worry', 'travels', 'noose', '42nd', 'disorder', 'awakened', 'i’m', 'represent', 'jewish', 'island', 'continent', 'chairs', 'smarting', 'sweet', 'threats', 'arching', 'hat', 'joke', "'you're", 'castigate', 'consuming', 'later', 'cafeterias', 'started', 'mass', 'executions', 'rocks', 'ordered', 'page', "here'", 'marked', 'monroe', 'zero', 'bartender', 'cure', 'speeded-up', 'allowed', 'routines', 'civilian', 'section', 'hump', 'somewhat', 'brothers', 'drifted', 'cannibal', 'factor', 'hoisted', 'lower', 'lust', 'writes', 'polishing', 'lee', 'whitest', 'unlucky', 'script', 'masturbate', "wife's", 'summoned', 'broken', 'pushes', 'photos', 'hung', 'chased', 'instruction', 'know', 'sidewalk', 'net', 'absorbed', 'notice', 'by', 'streets', 'geometric', 'managed', 'spelt', 'juke', 'saturn', 'ferry', 'glazed', 'eastern', 'plunger', 'nights', 'sprouted', 'whining', 'saturday', 'ago', 'curled', 'doll', 'formula', 'nasty', 'engineering', 'maine', 'mongolian', 'space', 'can-can', 'authority', 'cat', 'barbecue', 'tons', 'hard-on', 'prince', 'flickering', 'salesmen', 'auction', 'drift', 'industry', 'contains', 'figure', 'no', 'gentlemen', 'prickling', '`do', 'pearls', 'unworthy', 'list', 'leads', 'blind', 'track', 'place', 'insides', 'tapeworm', 'panting', 'prescription', 'burglar', 'pockets', 'frogs', 'scale', 'moans', 'gallant', 'calling', 'about', 'criada', 'exquisitries', 'types', 'down', 'sixty', 'guarded', 'collected', 'shivers', 'misunderstood', 'story', 'rang', 'think', 'shirt', 'voice', 'lets', 'heard', 'over', 'hold', 'time', 'hear', 'thoughts', 'manic', 'insects', 'cowboyed', 'active', 'location', 'someone', 'weak', 'understanding', 'mixture', 'global', 'spent', 'atrophied', 'wiped', "oxygen'", 'blown', 'swelled', 'licensed', 'stings', 'players', 'egg', 'workers', 'sleeve', 'all-around', 'fades', 'plucking', 'proudest', 'spears', 'bar', 'brushing', 'sinks', 'convolutions', 'society', 'top', 'positively', "we'll", 'dresser', 'pitchmen', 'identification', 'light', 'whisper', 'altered', 'way', 'university', 'kidney', 'this', 'future', 'eddies', 'code', 'lagoons', 'coffee', 'sput', 'right', 'hog', 'yourself', 'albino', 'whistled', 'host', 'fits', 'steak', 'freezed', 'sargasso', 'ash', 'forward', 'needle', 'absent', 'of', 'cunt', 'tourists', 'mud', 'check', 'silently', 'lu', 'whistles', 'roar', 'blood', 'drenched', 'money', 'lungs', 'toothpick', 'ovens', 'priest', 'function', 'shared', 'short-time', 'projector', 'lives', 'waste', "aren't", 'devious', 'dissolving', 'promising', 'wised', 'right', 'sniffing', 'issues', 'tucked', 'traffic', 'clause', 'idiots', 'serving', 'sadly', 'scream', 'step', 'brings', 'sheik', 'cell', 'growing', 'age', 'clutching', 'penetrated', 'coil', 'urinal', 'accrete', 'told', 'check', 'sticks', 'trak', 'child', 'whimpered', 'sky', 'robes', 'reasonable', 'pour', 'depends', 'aftosa', 'motion', 'party', 'chirps', 'slack', 'lai', 'hills', 'tangier', 'members', 'stretching', 'night', 'off', 'bows', 'fused', 'cancer', 'else', 'stone', 'focusing', 'hang', 'hiding', 'rampant', 'pile', 'shoeshine', 'purposes', 'banner', 'stood', 'flows', 'circumstances', 'deal', 'striptease', 'people', 'tracks', 'classic', 'antibiotics', 'mother', 'music', 'twittering', 'rhythms', 'returned', 'service', 'trees', 'inspectors', 'seeps', 'clean', 'somebody', 'rimmed', 'experienced', 'unqualified', 'spoon', 'warning', 'knows', 'puff', 'explosions', 'farts', 'giving', 'repeated', 'arm', 'syringe', 'sand', 'substitute', 'described', 'man', 'secondhand', 'creep', 'red', 'galaxy', 'possible', 'dusted', 'cock ...

# %%
with open(r'hoard.txt', 'w') as fp:
    for item in hoard:
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
with open("hoard.txt", "r") as f:
    word_list = [line.strip() for line in f if line.strip()]

# %%
naked_lunch = lunch.lower()
with open(r'naked_lunch.txt', 'w') as fp:
    fp.write(naked_lunch)
print('Done')
# Out:
# Done
